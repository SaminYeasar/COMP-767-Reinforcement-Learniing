# %% [markdown]
# ##################################################
# ##  Assignment 1
# ##  Problem 1(a)
# ##  Samin Yeasar Arnob
# ##  McGill ID: 260800927
# ##  COMP 767- Reinforcement Learning Winter 2019
# #################################################

# %% [markdown]
# ##########################################################
#
#
# ## (a) summarize the main results in the paper [1]
# [1] link: https://people.eecs.berkeley.edu/˜kjamieson/resources/bestArmSurvey.pdf
#
#
# ###########################################################

# %% [markdown]
#
#
# Comparison of sampling procedure :
#
#
# * Similarity :
# Sample complexity of Action Elimination, UCB, LUCB algorithms are very similar
# * Differences :
# For Action Elimination, it's hard to get the best arm until we do many pulls around figure 1 requires around 30 pulls in paper[1] . But for UBC and LUCB we can identify best arm very quickly as it gives large separation in first and second arm
#
#
# For different parameter result will be different but will hold the same qualitive shape of the curve. The sample complexity derived for LUCB is the best result for sampling strategy

# %% [markdown]
# #####################################################################################
#
#
# ## (b) Reproducing the results in Figure 1 of [1]
#
#
# #######################################################################################

# %%
from IPython.display import SVG

# %%
"""
arguments

run = 'Reproduce_Paper_Results' or 'Book_Example_10arm_Bandit'
Sampling_Strategy = 'Action_Elimination' or 'UCB'

"""

# !python Comparison_Sampling_Strategies.py --run='Reproduce_Paper_Results' --Sampling_Strategy='Action_Elimination' --n_trials=100 --n_time_steps=2000
# Out:
# Running Action Elimination
# Figure(640x480)0 complete

# %%
def show_svg():
    return SVG('Action_Elimination_Reproduce_Paper_Results.svg')
show_svg()

# %%
# !python Comparison_Sampling_Strategies.py --run='Reproduce_Paper_Results' --Sampling_Strategy='UCB' --n_trials=40 --n_time_steps=2000
# Out:
# Running UCB
# Figure(640x480)complete

# %%
def show_svg():
    return SVG('UCB_Reproduce_Paper_Results.svg')
show_svg()

# %% [markdown]
# ###########################################################################################################
#
#
# ## (c) Empirical comparison on the bandit problem provided in the Sutton & Barto book
#
#
# #############################################################################################################

# %%
# !python Comparison_Sampling_Strategies.py --run='Book_Example_10arm_Bandit' --Sampling_Strategy='Action_Elimination' --n_trials=100 --n_time_steps=4000
# Out:
# Running Action Elimination
# Figure(640x480)0 complete

# %%
def show_svg():
    return SVG('Action_Elimination_Book_Example_10arm_Bandit.svg')
show_svg()

# %%
# !python Comparison_Sampling_Strategies.py --run='Book_Example_10arm_Bandit' --Sampling_Strategy='UCB' --n_trials=40 --n_time_steps=4000
# Out:
# Running UCB
# Figure(640x480)complete

# %%
def show_svg():
    return SVG('UCB_Book_Example_10arm_Bandit.svg')
show_svg()

# %% [markdown]
# ## Report
# The fundamental finding of the paper that, Action Elimination require more pull than UCB is found if both case examples. Best arm for UCB can be identified at very early stage.

# %% [markdown]
# ###################################################
#
#
# ## (d)Application, where regret optimization would be more useful than best arm identification.
#
#
# ###################################################

# %% [markdown]
# When reward function of arms become a function of time regret optimization would be more useful. Total regret in cumalative over all time steps. When we do too much of exploration at the begining, even if we end up at optimal arm regret will be high. So when we have limited number of trials and we want our explore and exploit to be in a balanced way regret optimization would be best suited.
